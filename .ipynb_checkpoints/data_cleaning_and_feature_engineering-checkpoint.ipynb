# %%
import pandas as pd
import numpy as np

df = pd.read_csv("data/raw/telco_churn.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Controllo valori mancanti

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# customerID          0
# DeviceProtection    0
# TotalCharges        0
# MonthlyCharges      0
# PaymentMethod       0
# PaperlessBilling    0
# Contract            0
# StreamingMovies     0
# StreamingTV         0
# TechSupport         0
# OnlineBackup        0
# gender              0
# OnlineSecurity      0
# InternetService     0
# MultipleLines       0
# PhoneService        0
# tenure              0
# Dependents          0
# Partner             0
# SeniorCitizen       0
# Churn               0
# dtype: int64

# %% [markdown]
# ### Non sono presenti valori mancanti.

# %% [markdown]
# ---

# %% [markdown]
# ## Controllo valori speciali nei campi numerici

# %%
df['TotalCharges'].unique()[:10]
# Out:
# array(['29.85', '1889.5', '108.15', '1840.75', '151.65', '820.5',
#        '1949.4', '301.9', '3046.05', '3487.95'], dtype=object)

# %% [markdown]
# ---

# %% [markdown]
# ## Conversione della colonna TotalCharges in numerico

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %% [markdown]
# ## Ricontrolliamo i missing

# %%
df.isna().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ## Rimuovere i valori mancanti

# %%
df = df.dropna()
df.shape
# Out:
# (7032, 21)

# %% [markdown]
# Da 7043 righe siamo passati a 7032 righe

# %% [markdown]
# ---

# %% [markdown]
# ## Convertire la colonna target in numerica

# %% [markdown]
# Il modello di Machine Learning accetta solo numeri, quindi convertiamo la colonna target "Churn"

# %%
df['Churn'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['Churn'].value_counts()
# Out:
# Churn
# No     5163
# Yes    1869
# Name: count, dtype: int64

# %%
df['Churn'].dtype
# Out:
# dtype('O')

# %% [markdown]
# Questo significa che la colonna non ha un tipo standard riconosciuto da pandas.

# %% [markdown]
# Forziamo la colonna a tipo stringa prima di fare il mapping.

# %%
df['Churn'] = df['Churn'].astype(str) # converte in stringa
df['Churn'] = df['Churn'].map({'Yes': 1, 'No': 0})
df['Churn'].value_counts()
# Out:
# Churn
# 0    5163
# 1    1869
# Name: count, dtype: int64
